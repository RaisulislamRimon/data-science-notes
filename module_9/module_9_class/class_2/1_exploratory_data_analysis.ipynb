# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.style.use('fivethirtyeight')
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
data = pd.read_csv('taitanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# How many survived?

# %%
data['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Survived'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df = data['Survived'].value_counts()
df.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df = data['Survived'].value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# using pandas
df = data['Survived'].value_counts()
df.plot.pie(autopct='%.2f%%', shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
# using seaborn 
sns.countplot(x=data['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# using seaborn 
datalabel = sns.countplot(x=data['Survived'])
for i in datalabel.containers:
    datalabel.bar_label(i)

# %%
# using matplotlib
f, axe = plt.subplots(1, 2, figsize=(12, 5))
data['Survived'].value_counts().plot.pie(autopct='%.2f%%', ax=axe[0], shadow=True)
axe[0].set_title('Survived')
# ax[0].set_ylabel('Y Label')
# Out:
# Text(0.5, 1.0, 'Survived')

# %%
# using matplotlib
f, axe = plt.subplots(1, 2, figsize=(12, 5))
data['Survived'].value_counts().plot.pie(autopct='%.2f%%', ax=axe[0], shadow=True)
axe[0].set_title('Survived')
# ax[0].set_ylabel('Y Label')

datalabel = sns.countplot(x=data['Survived'], ax=axe[1], hue='Sex', data=data)
axe[1].set_title('Survived')
for i in datalabel.containers:
    datalabel.bar_label(i)
plt.show()

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex','Survived']]
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
data[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# ### How many Survived based on Sex??

# %%
f,ax=plt.subplots(1,2,figsize=(12,8))
datalabel=data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
for i in datalabel.containers:
    datalabel.bar_label(i)
ax[0].set_title('Survived vs Sex')

datalabel=sns.countplot(x='Sex',hue="Survived", data=data,ax=ax[1])
#datalabel=sns.countplot(x='Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
for i in datalabel.containers:
    datalabel.bar_label(i)
plt.show()

# %% [markdown]
# ## Pclass --> Ordinal Feature

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.Pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
data['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
data.Pclass.nunique()
# Out:
# 3

# %%
len(data.Pclass)
# Out:
# 891

# %%
len(data.Pclass.unique())
# Out:
# 3

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
pd.crosstab(data.Pclass, data.Survived)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(data.Survived, data.Pclass)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# ### How many Survived based on Pclass??

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))

#datalabel=data['Pclass'].value_counts().plot.bar(color=['#75FA8D','#FFDF00','#D3D3D3'],ax=ax[0])
datalabel=sns.countplot(x='Pclass',data=data,ax=ax[0])
for i in datalabel.containers:
    datalabel.bar_label(i)
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))

#datalabel=data['Pclass'].value_counts().plot.bar(color=['#75FA8D','#FFDF00','#D3D3D3'],ax=ax[0])
datalabel=sns.countplot(x='Pclass',data=data,ax=ax[0])
for i in datalabel.containers:
    datalabel.bar_label(i)
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

datalabel=sns.countplot(x='Pclass',hue='Survived',data=data,ax=ax[1])

for i in datalabel.containers:
    datalabel.bar_label(i)
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))

#datalabel=data['Pclass'].value_counts().plot.bar(color=['#75FA8D','#FFDF00','#D3D3D3'],ax=ax[0])
datalabel=sns.countplot(x='Pclass',data=data,ax=ax[0])
for i in datalabel.containers:
    datalabel.bar_label(i)
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

datalabel=sns.countplot(x='Pclass',hue='Sex',data=data,ax=ax[1])

for i in datalabel.containers:
    datalabel.bar_label(i)
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass)
# Out:
# Pclass            1   2    3
# Sex    Survived
# female 0          3   6   72
#        1         91  70   72
# male   0         77  91  300
#        1         45  17   47

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass).plot.bar()
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
sns.catplot(x="Sex", y="Survived", data=data)

# sns.catplot(x="Sex", y="Survived", kind="bar", data=data)
    
plt.show()

# %%
sns.catplot(x="Sex", y="Survived", kind="point", data=data)

# sns.catplot(x="Sex", y="Survived", kind="bar", data=data)
    
plt.show()

# %%
#sns.catplot(x="Sex", y="Survived", kind="point", data=data)

sns.catplot(x="Sex", y="Survived", kind="bar", data=data)
    
plt.show()

# %%
#sns.catplot(x="Sex", y="Survived", kind="point", data=data)

sns.catplot(x="Sex", y="Survived", col="Pclass", kind="bar", data=data)
    
plt.show()

# %%
sns.catplot(x="Sex", y="Survived", kind="point", data=data)

# sns.catplot(x="Sex", y="Survived", col="Pclass", kind="bar", data=data)
    
plt.show()

# %%
sns.catplot(x="Sex", y="Survived", kind="point", data=data, col='Pclass')

# sns.catplot(x="Sex", y="Survived", col="Pclass", kind="bar", data=data)
    
plt.show()

# %%
sns.catplot(x="Sex", y="Survived", col="Pclass", kind="point", data=data)
    
plt.show()

# %% [markdown]
# ## Age--> Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
# violin plot
f,ax=plt.subplots(figsize=(10,5))
sns.violinplot(x="Pclass",y="Age", data=data, ax=ax)
ax.set_title('Pclass and Age')
ax.set_yticks(range(0,110,10))
plt.show()

# %%
# violin plot
f,ax=plt.subplots(figsize=(10,8))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data, ax=ax)
ax.set_title('Pclass and Age')
ax.set_yticks(range(0,110,10))
plt.show()

# %%
# violin plot
f,ax=plt.subplots(figsize=(10,5))
sns.violinplot(x="Pclass",y="Age", hue="Survived",split=True, data=data, ax=ax)
ax.set_title('Pclass and Age')
ax.set_yticks(range(0,110,10))
plt.show()

# %%
# violin plot
f,ax=plt.subplots(1,2,figsize=(12,5))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))

sns.violinplot(x="Sex",y="Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Initial'] = 'other'
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Initial
# 0        0         A/5 21171   7.2500   NaN        S   other
# 1        0          PC 17599  71.2833   C85        C   other
# 2        0  STON/O2. 3101282   7.9250   NaN        S   other
# 3        0            113803  53.1000  C123        S   other
# 4        0            373450   8.0500   NaN        S   other
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S   other
# 887      0            112053  30.0000   B42        S   other
# 888      2        W./C. 6607  23.4500   NaN        S   other
# 889      0            111369  30.0000  C148        C   other
# 890      0            370376   7.7500   NaN        Q   other
#
# [891 rows x 13 columns]

# %%
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Initial
# 0        0         A/5 21171   7.2500   NaN        S      Mr
# 1        0          PC 17599  71.2833   C85        C     Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3        0            113803  53.1000  C123        S     Mrs
# 4        0            373450   8.0500   NaN        S      Mr
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S     Rev
# 887      0            112053  30.0000   B42        S    Miss
# 888      2        W./C. 6607  23.4500   NaN        S    Miss
# 889      0            111369  30.0000  C148        C      Mr
# 890      0            370376   7.7500   NaN        Q      Mr
#
# [891 rows x 13 columns]

# %%
pd.crosstab(data.Initial, data.Sex)
# Out:
# Sex       female  male
# Initial
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
pd.crosstab(data.Initial, data.Sex).T
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
# pip install Jinja2

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient() 
#Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_0f88b_row0_col0, #T_0f88b_row0_col1, #T_0f88b_row0_col3, #T_0f88b_row0_col4, #T_0f88b_row0_col5, #T_0f88b_row0_col7, #T_0f88b_row0_col8, #T_0f88b_row0_col12, #T_0f88b_row0_col15, #T_0f88b_row0_col16, #T_0f88b_row1_col2, #T_0f88b_row1_col6, #T_0f88b_row1_col9, #T_0f88b_row1_col10, #T_0f88b_row1_col11, #T_0f88b_row1_col13, #T_0f88b_row1_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0f88b_row0_col2, #T_0f88b_row0_col6, #T_0f88b_row0_col9, #T_0f88b_row0_col10, #T_0f88b_row0_col11, #T_0f88b_row0_col13, #T_0f88b_row0_col14, #T_0f88b_row1_col0, #T_0f88b_row1_col1, #T_0f88b_row1_col3, #T_0f88b_row1_col4, #T_0f88b_row1_col5, #T_0f88b_row1_col7, #T_0f88b_row1_col8, #T_0f88b_row1_col12, #T_0f88b_row1_col15, #T_0f88b_row1_col16 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f88b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_0f88b_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_0f88b_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_0f88b_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_0f88b_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_0f88b_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_0f88b_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_0f88b_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_0f88b_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_0f88b_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_0f88b_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_0f88b_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_0f88b_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_0f88b_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_0f88b_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_0f88b_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_0f88b_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_0f88b_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f88b_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_0f88b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0f88b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0f88b_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_0f88b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0f88b_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_0f88b_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_0f88b_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_0f88b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_0f88b_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_0f88b_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_0f88b_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_0f88b_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_0f88b_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_0f88b_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_0f88b_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_0f88b_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_0f88b_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0f88b_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_0f88b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0f88b_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_0f88b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0f88b_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_0f88b_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_0f88b_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_0f88b_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_0f88b_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_0f88b_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_0f88b_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_0f88b_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_0f88b_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_0f88b_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_0f88b_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_0f88b_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_0f88b_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_0f88b_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Initial'].replace(['Mlle','Mme','Ms',   'Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                        ['Miss','Miss','Miss','Mr','Mr',  'Mrs',   'Mrs',    'Mr', 'Mr','Mr','Mr','Mr','Mr'],
                        inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Initial
# 0        0         A/5 21171   7.2500   NaN        S      Mr
# 1        0          PC 17599  71.2833   C85        C     Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3        0            113803  53.1000  C123        S     Mrs
# 4        0            373450   8.0500   NaN        S      Mr
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S      Mr
# 887      0            112053  30.0000   B42        S    Miss
# 888      2        W./C. 6607  23.4500   NaN        S    Miss
# 889      0            111369  30.0000  C148        C      Mr
# 890      0            370376   7.7500   NaN        Q      Mr
#
# [891 rows x 13 columns]

# %%
data.Initial.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_eb072_row0_col0, #T_eb072_row0_col2, #T_eb072_row1_col1, #T_eb072_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_eb072_row0_col1, #T_eb072_row0_col3, #T_eb072_row1_col0, #T_eb072_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb072">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_eb072_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_eb072_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_eb072_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_eb072_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb072_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_eb072_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_eb072_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_eb072_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_eb072_row0_col3" class="data row0 col3" >127</td>
#     </tr>
#     <tr>
#       <th id="T_eb072_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_eb072_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_eb072_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_eb072_row1_col2" class="data row1 col2" >537</td>
#       <td id="T_eb072_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        33.022727
# Mrs       35.981818
# Name: Age, dtype: float64

# %% [markdown]
# ### Filling NaN Ages

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Initial          0
# dtype: int64

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr')]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 5              6         0       3              Moran, Mr. James  male  NaN
# 17            18         1       2  Williams, Mr. Charles Eugene  male  NaN
# 26            27         0       3       Emir, Mr. Farred Chehab  male  NaN
# 29            30         0       3           Todoroff, Mr. Lalio  male  NaN
# 36            37         1       3              Mamee, Mr. Hanna  male  NaN
# ..           ...       ...     ...                           ...   ...  ...
# 839          840         1       1          Marechal, Mr. Pierre  male  NaN
# 846          847         0       3      Sage, Mr. Douglas Bullen  male  NaN
# 859          860         0       3              Razi, Mr. Raihed  male  NaN
# 868          869         0       3   van Melkebeke, Mr. Philemon  male  NaN
# 878          879         0       3            Laleff, Mr. Kristo  male  NaN
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked Initial
# 5        0      0    330877   8.4583   NaN        Q      Mr
# 17       0      0    244373  13.0000   NaN        S      Mr
# 26       0      0      2631   7.2250   NaN        C      Mr
# 29       0      0    349216   7.8958   NaN        S      Mr
# 36       0      0      2677   7.2292   NaN        C      Mr
# ..     ...    ...       ...      ...   ...      ...     ...
# 839      0      0     11774  29.7000   C47        C      Mr
# 846      8      2  CA. 2343  69.5500   NaN        S      Mr
# 859      0      0      2629   7.2292   NaN        C      Mr
# 868      0      0    345777   9.5000   NaN        S      Mr
# 878      0      0    349217   7.8958   NaN        S      Mr
#
# [120 rows x 13 columns]

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22

# %%
data.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)

data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)

plt.show()

# %%
data[data.Age == 80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked Initial
# 630  male  80.0      0      0  27042  30.0   A23        S      Mr

# %% [markdown]
# ### Observations:
# 1)The Toddlers(age<5) were saved in large numbers(The Women and Child First Policy).
#
# 2)The oldest Passenger was saved(80 years).
#
# 3)Maximum number of deaths were in the age group of 30-40.

# %%
# sns.factorplot('Pclass','Survived',col='Initial',data=data)
sns.catplot(x="Pclass", y="Survived", col="Initial", kind="point", data=data)
plt.show()

# %% [markdown]
# The Women and Child first policy thus holds true irrespective of the class.

# %% [markdown]
# ### Chances for Survival by Port Of Embarkation

# %%
sns.catplot(x='Embarked',y='Survived', kind="point", data=data)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
# catplot is not supporting ax
f,ax=plt.subplots(figsize=(10,8))
sns.catplot(x='Embarked',y='Survived', kind="point", data=data)

# f,ax=plt.subplots(figsize=(10,8))
# sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data, ax=ax)
plt.show()
