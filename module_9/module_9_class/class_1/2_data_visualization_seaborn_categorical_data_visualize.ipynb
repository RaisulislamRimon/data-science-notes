# %%
import seaborn as sns 
import pandas as pd 
import numpy as np 
import warnings 
warnings.filterwarnings('ignore')

# %%
# check all the versions  of imported packages 
print('seaborn version: ', sns.__version__)
print('numpy version: ', np.__version__)
print('pandas version: ', pd.__version__)
# Out:
# seaborn version:  0.13.2
# numpy version:  2.1.3
# pandas version:  2.2.3

# %%
tips = sns.get_dataset_names()
tips
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# categorical data:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
type(tips['day'].unique())
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
tips[tips['day'] == 'Thur']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 7 columns]

# %%
tips[tips['day'] == 'Fri']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2
# 99        12.46  1.50    Male     No  Fri  Dinner     2
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2
# 220       12.16  2.20    Male    Yes  Fri   Lunch     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Categorical ScatterPlot:
#
# stripplot()

# %%
sns.stripplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', jitter=False, data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', jitter=False, data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# swarmplot( )

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt 
# plt.legend(loc='upper right')

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time')
plt.legend(loc='upper right')

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time', palette='coolwarm')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='time', palette='Oranges')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# boxplot()

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='Oranges')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')
plt.legend(loc='upper right')

# %% [markdown]
# violinplot()

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
plt.legend(loc='upper right')

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# barplot()

# %%
tips[tips['day'] == 'Thur']['total_bill'].mean()
# Out:
# np.float64(17.682741935483868)

# %%
sns.barplot(x='day', y='total_bill', data=tips) # it will show mean of total_bill by default
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# sns.barplot(x='day', y='total_bill', data=tips) # it will show mean of total_bill by default
datalabel = sns.barplot(x='day', y='total_bill', data=tips, estimator=np.sum) # it will show mean of total_bill by default

for i in datalabel.containers:
    datalabel.bar_label(i)

# %%
import numpy as np 
datalabel = sns.barplot(x='day', y='total_bill', data=tips, estimator=np.sum)

# %%
import numpy as np 
datalabel = sns.barplot(x='day', y='total_bill', data=tips, estimator=np.sum)

for i in datalabel.containers:
    datalabel.bar_label(i)

# %%
import numpy as np 
datalabel = sns.barplot(x='day', y='total_bill', data=tips, estimator=np.sum, ci=None)

for i in datalabel.containers:
    datalabel.bar_label(i)

# %% [markdown]
# countplot()

# %%
tips[tips['day'] == 'Sat']['total_bill'].count()
# Out:
# np.int64(87)

# %%
sns.countplot(x='day', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='day', hue='sex', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
datalabel = sns.countplot(x='day', hue='sex', data=tips)
for i in datalabel.containers:
    datalabel.bar_label(i)

# %%
sns.countplot(x='size', data=tips)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
datalabel = sns.countplot(x='size', data=tips)
for i in datalabel.containers:
    datalabel.bar_label(i)
