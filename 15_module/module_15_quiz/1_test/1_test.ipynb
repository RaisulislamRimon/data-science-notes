# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here, What would be the calculated value of y and z?
#
# Note that, euler's number = 2.718

# %% [markdown]
# Answer:

# %% [markdown]
# Given,
#
# Age (x) = 40
#
# y = 0.042 * x - 1.53
#
# z = 1 / (1 + e^(-y))
#
# Euler's number (e) = 2.718

# %% [markdown]
# Step 1: Calculate y
#
# y = 0.042 * 40 - 1.53
#
# y = 1.68 - 1.53
#
# y = 0.15

# %% [markdown]
# Step 2: Calculate z
#
# z = 1 / (1 + e^(-0.15))
#
# z = 1 / (1 + 2.718^(-0.15))
#
# z = 1 / (1 + 0.8607)
#
# z = 1 / 1.8607
#
# z = 0.5374

# %% [markdown]
# Results:
#
# y = 0.15
#
# z = 0.5374

# %% [markdown]
# Code:

# %%
import math

# Given values
x = 40

# Calculate y
y = 0.042 * x - 1.53

# Calculate z 
z = 1 / (1 + math.exp(-y))

# Print the results
print("y =", y)
print("z =", z)
# Out:
# y = 0.15000000000000013
# z = 0.5374298453437496

# %%
y = 0.15000000000000013
z = 0.5374298453437496
