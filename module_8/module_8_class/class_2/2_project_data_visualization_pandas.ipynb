# %% [markdown]
# Pandas Built-in Data Visualization

# %%
# pip install numpy

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# pip install matplotlib

# %%
import matplotlib as mtl
print("Numpy version: ", np.__version__)
print("Pandas version: ", pd.__version__)
print("Matplotlib version: ", mtl.__version__)
# Out:
# Numpy version:  2.1.3
# Pandas version:  2.2.3
# Matplotlib version:  3.9.3

# %%
data1 = np.random.randn(500, 3)
data1
# Out:
# array([[-1.08719051, -2.48122392,  0.52104998],
#        [-1.0743244 , -0.73793395,  0.05829923],
#        [-0.20626212,  0.63358075, -1.92649363],
#        ...,
#        [-1.31549236, -0.97213661, -1.71780197],
#        [ 0.64256977, -0.06038482,  1.08341087],
#        [ 1.86130031,  0.23188116, -0.78275162]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1 = pd.DataFrame(data=data1, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#             A         B         C
# 0   -1.087191 -2.481224  0.521050
# 1   -1.074324 -0.737934  0.058299
# 2   -0.206262  0.633581 -1.926494
# 3   -0.553412 -1.880427 -0.155721
# 4    0.575373  0.910451  1.039269
# ..        ...       ...       ...
# 495 -0.937953  1.021913  0.785183
# 496 -0.387076 -1.139207 -0.099401
# 497 -1.315492 -0.972137 -1.717802
# 498  0.642570 -0.060385  1.083411
# 499  1.861300  0.231881 -0.782752
#
# [500 rows x 3 columns]

# %%
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#             A         B         C         D
# 0   -1.087191 -2.481224  0.521050  0.826964
# 1   -1.074324 -0.737934  0.058299  0.951619
# 2   -0.206262  0.633581 -1.926494  0.182427
# 3   -0.553412 -1.880427 -0.155721  0.934205
# 4    0.575373  0.910451  1.039269  0.092132
# ..        ...       ...       ...       ...
# 495 -0.937953  1.021913  0.785183  0.817488
# 496 -0.387076 -1.139207 -0.099401  0.096984
# 497 -1.315492 -0.972137 -1.717802  0.612961
# 498  0.642570 -0.060385  1.083411  0.956982
# 499  1.861300  0.231881 -0.782752  0.718475
#
# [500 rows x 4 columns]

# %% [markdown]
# Generating DataFrame2 - df2

# %%
data2 = np.random.rand(20, 3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data=data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0   0.815495  0.862902  0.325930
# 1   0.067012  0.243447  0.592866
# 2   0.338438  0.061755  0.451737
# 3   0.973598  0.251953  0.252800
# 4   0.553578  0.136520  0.660205
# 5   0.099616  0.047320  0.180257
# 6   0.194366  0.303138  0.683836
# 7   0.988401  0.349446  0.179081
# 8   0.525754  0.548035  0.526622
# 9   0.334494  0.476905  0.611802
# 10  0.619407  0.997574  0.865507
# 11  0.343241  0.321927  0.966111
# 12  0.496309  0.332825  0.057902
# 13  0.024518  0.813686  0.720853
# 14  0.527454  0.745845  0.058458
# 15  0.586760  0.629821  0.119778
# 16  0.166468  0.303071  0.298697
# 17  0.468054  0.058496  0.478428
# 18  0.545245  0.283504  0.684016
# 19  0.189704  0.193392  0.357648

# %% [markdown]
# Histogram(single variable)

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black', bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=2, edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black', figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5), bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
# df1['A'].plot(kind="hist", bins=30)
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use("fivethirtyeight")
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.815495  0.862902  0.325930
# 1   0.067012  0.243447  0.592866
# 2   0.338438  0.061755  0.451737
# 3   0.973598  0.251953  0.252800
# 4   0.553578  0.136520  0.660205
# 5   0.099616  0.047320  0.180257
# 6   0.194366  0.303138  0.683836
# 7   0.988401  0.349446  0.179081
# 8   0.525754  0.548035  0.526622
# 9   0.334494  0.476905  0.611802
# 10  0.619407  0.997574  0.865507
# 11  0.343241  0.321927  0.966111
# 12  0.496309  0.332825  0.057902
# 13  0.024518  0.813686  0.720853
# 14  0.527454  0.745845  0.058458
# 15  0.586760  0.629821  0.119778
# 16  0.166468  0.303071  0.298697
# 17  0.468054  0.058496  0.478428
# 18  0.545245  0.283504  0.684016
# 19  0.189704  0.193392  0.357648

# %%
plt.style.use("dark_background")

# %%
df2['X'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.hist();

# %%
df2.hist();

# %% [markdown]
# Plot Types

# %%
# by default - line chart
df2['X'].plot()
# in x axis: index number
# in y axis: column values of x
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.815495  0.862902  0.325930
# 1   0.067012  0.243447  0.592866
# 2   0.338438  0.061755  0.451737
# 3   0.973598  0.251953  0.252800
# 4   0.553578  0.136520  0.660205
# 5   0.099616  0.047320  0.180257
# 6   0.194366  0.303138  0.683836
# 7   0.988401  0.349446  0.179081
# 8   0.525754  0.548035  0.526622
# 9   0.334494  0.476905  0.611802
# 10  0.619407  0.997574  0.865507
# 11  0.343241  0.321927  0.966111
# 12  0.496309  0.332825  0.057902
# 13  0.024518  0.813686  0.720853
# 14  0.527454  0.745845  0.058458
# 15  0.586760  0.629821  0.119778
# 16  0.166468  0.303071  0.298697
# 17  0.468054  0.058496  0.478428
# 18  0.545245  0.283504  0.684016
# 19  0.189704  0.193392  0.357648

# %%
df2.plot();

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.815495  0.862902  0.325930
# 1   0.067012  0.243447  0.592866
# 2   0.338438  0.061755  0.451737
# 3   0.973598  0.251953  0.252800
# 4   0.553578  0.136520  0.660205
# 5   0.099616  0.047320  0.180257
# 6   0.194366  0.303138  0.683836
# 7   0.988401  0.349446  0.179081
# 8   0.525754  0.548035  0.526622
# 9   0.334494  0.476905  0.611802
# 10  0.619407  0.997574  0.865507
# 11  0.343241  0.321927  0.966111
# 12  0.496309  0.332825  0.057902
# 13  0.024518  0.813686  0.720853
# 14  0.527454  0.745845  0.058458
# 15  0.586760  0.629821  0.119778
# 16  0.166468  0.303071  0.298697
# 17  0.468054  0.058496  0.478428
# 18  0.545245  0.283504  0.684016
# 19  0.189704  0.193392  0.357648

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
# df2.plot(stacked=True);
df2.plot(kind='bar', stacked=True);

# %%
# df2.plot(x='X', y='Y', stacked=True);;
# df2.plot(kind='bar', stacked=True);

# %%
# df2['X'].plot(kind='area')

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.815495  0.862902  0.325930
# 1   0.067012  0.243447  0.592866
# 2   0.338438  0.061755  0.451737
# 3   0.973598  0.251953  0.252800
# 4   0.553578  0.136520  0.660205
# 5   0.099616  0.047320  0.180257
# 6   0.194366  0.303138  0.683836
# 7   0.988401  0.349446  0.179081
# 8   0.525754  0.548035  0.526622
# 9   0.334494  0.476905  0.611802
# 10  0.619407  0.997574  0.865507
# 11  0.343241  0.321927  0.966111
# 12  0.496309  0.332825  0.057902
# 13  0.024518  0.813686  0.720853
# 14  0.527454  0.745845  0.058458
# 15  0.586760  0.629821  0.119778
# 16  0.166468  0.303071  0.298697
# 17  0.468054  0.058496  0.478428
# 18  0.545245  0.283504  0.684016
# 19  0.189704  0.193392  0.357648

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y')
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 5))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot.scatter(x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot(kind='area')
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.area(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# Bar Plot

# %%
df2
# Out:
#            X         Y         Z
# 0   0.815495  0.862902  0.325930
# 1   0.067012  0.243447  0.592866
# 2   0.338438  0.061755  0.451737
# 3   0.973598  0.251953  0.252800
# 4   0.553578  0.136520  0.660205
# 5   0.099616  0.047320  0.180257
# 6   0.194366  0.303138  0.683836
# 7   0.988401  0.349446  0.179081
# 8   0.525754  0.548035  0.526622
# 9   0.334494  0.476905  0.611802
# 10  0.619407  0.997574  0.865507
# 11  0.343241  0.321927  0.966111
# 12  0.496309  0.332825  0.057902
# 13  0.024518  0.813686  0.720853
# 14  0.527454  0.745845  0.058458
# 15  0.586760  0.629821  0.119778
# 16  0.166468  0.303071  0.298697
# 17  0.468054  0.058496  0.478428
# 18  0.545245  0.283504  0.684016
# 19  0.189704  0.193392  0.357648

# %%
df2['X'].plot.bar(figsize=(15, 5))
# Out:
# <Axes: >

# %%
df2['X'].plot.bar(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.barh(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 5))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 5), stacked=True)
# Out:
# <Axes: >

# %%
df1
# Out:
#             A         B         C         D
# 0   -1.087191 -2.481224  0.521050  0.826964
# 1   -1.074324 -0.737934  0.058299  0.951619
# 2   -0.206262  0.633581 -1.926494  0.182427
# 3   -0.553412 -1.880427 -0.155721  0.934205
# 4    0.575373  0.910451  1.039269  0.092132
# ..        ...       ...       ...       ...
# 495 -0.937953  1.021913  0.785183  0.817488
# 496 -0.387076 -1.139207 -0.099401  0.096984
# 497 -1.315492 -0.972137 -1.717802  0.612961
# 498  0.642570 -0.060385  1.083411  0.956982
# 499  1.861300  0.231881 -0.782752  0.718475
#
# [500 rows x 4 columns]

# %%
df1.plot.scatter(x='A', y='B', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.line(x='A', y='B', figsize=(12, 3), lw=1)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.line(x='A', y='B', figsize=(12, 3), lw=.5)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.scatter(x='A', y='B', c='0.8', cmap='coolwarm', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Bubble Chart

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=90, figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=10, figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'], figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'] * 100, figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'] * 100, c='D', cmap='coolwarm', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', gridsize=30, cmap='Oranges', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Line Plot

# %% [markdown]
# Project: Data Visualization from csv file

# %%
gas = pd.read_csv('gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...
