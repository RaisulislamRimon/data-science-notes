# %% [markdown]
# Pandas Built-in Data Visualization

# %%
# pip install numpy

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# pip install matplotlib

# %%
import matplotlib as mtl
print("Numpy version: ", np.__version__)
print("Pandas version: ", pd.__version__)
print("Matplotlib version: ", mtl.__version__)
# Out:
# Numpy version:  2.1.3
# Pandas version:  2.2.3
# Matplotlib version:  3.9.3

# %%
data1 = np.random.randn(500, 3)
data1
# Out:
# array([[ 0.48225385,  1.46015624, -0.41333421],
#        [-0.02573743,  1.42126207, -0.29581415],
#        [-1.37638928, -0.11157049,  0.76301557],
#        ...,
#        [-1.32542594, -0.25255972,  1.13002161],
#        [-0.13416102,  0.75726247,  0.91010823],
#        [-0.40164035,  0.44994352, -1.08515526]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1 = pd.DataFrame(data=data1, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#             A         B         C
# 0    0.482254  1.460156 -0.413334
# 1   -0.025737  1.421262 -0.295814
# 2   -1.376389 -0.111570  0.763016
# 3    0.739286 -0.887205 -0.202314
# 4   -0.932713 -0.530892  0.851889
# ..        ...       ...       ...
# 495  1.685109 -0.741624  1.060700
# 496 -1.407481  1.943074 -1.202310
# 497 -1.325426 -0.252560  1.130022
# 498 -0.134161  0.757262  0.910108
# 499 -0.401640  0.449944 -1.085155
#
# [500 rows x 3 columns]

# %%
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#             A         B         C         D
# 0    0.482254  1.460156 -0.413334  0.401297
# 1   -0.025737  1.421262 -0.295814  0.465077
# 2   -1.376389 -0.111570  0.763016  0.326824
# 3    0.739286 -0.887205 -0.202314  0.718287
# 4   -0.932713 -0.530892  0.851889  0.963833
# ..        ...       ...       ...       ...
# 495  1.685109 -0.741624  1.060700  0.756470
# 496 -1.407481  1.943074 -1.202310  0.536550
# 497 -1.325426 -0.252560  1.130022  0.733127
# 498 -0.134161  0.757262  0.910108  0.288501
# 499 -0.401640  0.449944 -1.085155  0.642832
#
# [500 rows x 4 columns]

# %% [markdown]
# Generating DataFrame2 - df2

# %%
data2 = np.random.rand(20, 3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data=data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0   0.233390  0.435945  0.913539
# 1   0.304778  0.486403  0.496408
# 2   0.755676  0.937464  0.647119
# 3   0.938905  0.967546  0.526732
# 4   0.899553  0.909762  0.522569
# 5   0.944627  0.886940  0.286280
# 6   0.605004  0.097099  0.065841
# 7   0.906967  0.147911  0.057262
# 8   0.588719  0.714367  0.691805
# 9   0.883648  0.529652  0.783756
# 10  0.537027  0.343443  0.603189
# 11  0.530414  0.888313  0.550794
# 12  0.590481  0.997722  0.494143
# 13  0.700752  0.616153  0.505216
# 14  0.004947  0.567091  0.218753
# 15  0.148756  0.153722  0.143333
# 16  0.793530  0.499985  0.798117
# 17  0.288298  0.116477  0.135827
# 18  0.236648  0.942994  0.090960
# 19  0.340146  0.057464  0.823157

# %% [markdown]
# Histogram(single variable)

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black', bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=2, edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black', figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5), bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
# df1['A'].plot(kind="hist", bins=30)
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use("fivethirtyeight")
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.233390  0.435945  0.913539
# 1   0.304778  0.486403  0.496408
# 2   0.755676  0.937464  0.647119
# 3   0.938905  0.967546  0.526732
# 4   0.899553  0.909762  0.522569
# 5   0.944627  0.886940  0.286280
# 6   0.605004  0.097099  0.065841
# 7   0.906967  0.147911  0.057262
# 8   0.588719  0.714367  0.691805
# 9   0.883648  0.529652  0.783756
# 10  0.537027  0.343443  0.603189
# 11  0.530414  0.888313  0.550794
# 12  0.590481  0.997722  0.494143
# 13  0.700752  0.616153  0.505216
# 14  0.004947  0.567091  0.218753
# 15  0.148756  0.153722  0.143333
# 16  0.793530  0.499985  0.798117
# 17  0.288298  0.116477  0.135827
# 18  0.236648  0.942994  0.090960
# 19  0.340146  0.057464  0.823157

# %%
plt.style.use("dark_background")

# %%
df2['X'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.hist();

# %%
df2.hist();

# %% [markdown]
# Plot Types

# %%
# by default - line chart
df2['X'].plot()
# in x axis: index number
# in y axis: column values of x
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.233390  0.435945  0.913539
# 1   0.304778  0.486403  0.496408
# 2   0.755676  0.937464  0.647119
# 3   0.938905  0.967546  0.526732
# 4   0.899553  0.909762  0.522569
# 5   0.944627  0.886940  0.286280
# 6   0.605004  0.097099  0.065841
# 7   0.906967  0.147911  0.057262
# 8   0.588719  0.714367  0.691805
# 9   0.883648  0.529652  0.783756
# 10  0.537027  0.343443  0.603189
# 11  0.530414  0.888313  0.550794
# 12  0.590481  0.997722  0.494143
# 13  0.700752  0.616153  0.505216
# 14  0.004947  0.567091  0.218753
# 15  0.148756  0.153722  0.143333
# 16  0.793530  0.499985  0.798117
# 17  0.288298  0.116477  0.135827
# 18  0.236648  0.942994  0.090960
# 19  0.340146  0.057464  0.823157

# %%
df2.plot();

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.233390  0.435945  0.913539
# 1   0.304778  0.486403  0.496408
# 2   0.755676  0.937464  0.647119
# 3   0.938905  0.967546  0.526732
# 4   0.899553  0.909762  0.522569
# 5   0.944627  0.886940  0.286280
# 6   0.605004  0.097099  0.065841
# 7   0.906967  0.147911  0.057262
# 8   0.588719  0.714367  0.691805
# 9   0.883648  0.529652  0.783756
# 10  0.537027  0.343443  0.603189
# 11  0.530414  0.888313  0.550794
# 12  0.590481  0.997722  0.494143
# 13  0.700752  0.616153  0.505216
# 14  0.004947  0.567091  0.218753
# 15  0.148756  0.153722  0.143333
# 16  0.793530  0.499985  0.798117
# 17  0.288298  0.116477  0.135827
# 18  0.236648  0.942994  0.090960
# 19  0.340146  0.057464  0.823157

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
# df2.plot(stacked=True);
df2.plot(kind='bar', stacked=True);

# %%
# df2.plot(x='X', y='Y', stacked=True);;
# df2.plot(kind='bar', stacked=True);

# %%
# df2['X'].plot(kind='area')

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.233390  0.435945  0.913539
# 1   0.304778  0.486403  0.496408
# 2   0.755676  0.937464  0.647119
# 3   0.938905  0.967546  0.526732
# 4   0.899553  0.909762  0.522569
# 5   0.944627  0.886940  0.286280
# 6   0.605004  0.097099  0.065841
# 7   0.906967  0.147911  0.057262
# 8   0.588719  0.714367  0.691805
# 9   0.883648  0.529652  0.783756
# 10  0.537027  0.343443  0.603189
# 11  0.530414  0.888313  0.550794
# 12  0.590481  0.997722  0.494143
# 13  0.700752  0.616153  0.505216
# 14  0.004947  0.567091  0.218753
# 15  0.148756  0.153722  0.143333
# 16  0.793530  0.499985  0.798117
# 17  0.288298  0.116477  0.135827
# 18  0.236648  0.942994  0.090960
# 19  0.340146  0.057464  0.823157

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y')
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 5))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot.scatter(x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot(kind='area')
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.area(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# Bar Plot

# %%
df2
# Out:
#            X         Y         Z
# 0   0.233390  0.435945  0.913539
# 1   0.304778  0.486403  0.496408
# 2   0.755676  0.937464  0.647119
# 3   0.938905  0.967546  0.526732
# 4   0.899553  0.909762  0.522569
# 5   0.944627  0.886940  0.286280
# 6   0.605004  0.097099  0.065841
# 7   0.906967  0.147911  0.057262
# 8   0.588719  0.714367  0.691805
# 9   0.883648  0.529652  0.783756
# 10  0.537027  0.343443  0.603189
# 11  0.530414  0.888313  0.550794
# 12  0.590481  0.997722  0.494143
# 13  0.700752  0.616153  0.505216
# 14  0.004947  0.567091  0.218753
# 15  0.148756  0.153722  0.143333
# 16  0.793530  0.499985  0.798117
# 17  0.288298  0.116477  0.135827
# 18  0.236648  0.942994  0.090960
# 19  0.340146  0.057464  0.823157

# %%
df2['X'].plot.bar(figsize=(15, 5))
# Out:
# <Axes: >

# %%
df2['X'].plot.bar(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.barh(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 5))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 5), stacked=True)
# Out:
# <Axes: >

# %%
df1
# Out:
#             A         B         C         D
# 0    0.482254  1.460156 -0.413334  0.401297
# 1   -0.025737  1.421262 -0.295814  0.465077
# 2   -1.376389 -0.111570  0.763016  0.326824
# 3    0.739286 -0.887205 -0.202314  0.718287
# 4   -0.932713 -0.530892  0.851889  0.963833
# ..        ...       ...       ...       ...
# 495  1.685109 -0.741624  1.060700  0.756470
# 496 -1.407481  1.943074 -1.202310  0.536550
# 497 -1.325426 -0.252560  1.130022  0.733127
# 498 -0.134161  0.757262  0.910108  0.288501
# 499 -0.401640  0.449944 -1.085155  0.642832
#
# [500 rows x 4 columns]

# %%
df1.plot.scatter(x='A', y='B', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.line(x='A', y='B', figsize=(12, 3), lw=1)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.line(x='A', y='B', figsize=(12, 3), lw=.5)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.scatter(x='A', y='B', c='0.8', cmap='coolwarm', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Bubble Chart

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=90, figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=10, figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'], figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'] * 100, figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'] * 100, c='D', cmap='coolwarm', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', gridsize=30, cmap='Oranges', figsize=(12, 3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Line Plot

# %% [markdown]
# Project: Data Visualization from csv file
