# %% [markdown]
# Pandas Built-in Data Visualization

# %%
# pip install numpy

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# pip install matplotlib

# %%
import matplotlib as mtl
mtl.__version__
# Out:
# '3.9.3'

# %%
data1 = np.random.randn(500, 3)
data1
# Out:
# array([[-1.33788138, -1.28392859, -0.81983138],
#        [ 1.15207614,  0.70410522,  1.32474376],
#        [ 1.85441429,  0.41824413, -0.78068406],
#        ...,
#        [ 0.64136685, -1.87162654,  1.88938898],
#        [-0.91220836,  1.99637398,  0.38743618],
#        [-0.03623422,  1.60259712,  0.8536153 ]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1 = pd.DataFrame(data=data1, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#             A         B         C
# 0   -1.337881 -1.283929 -0.819831
# 1    1.152076  0.704105  1.324744
# 2    1.854414  0.418244 -0.780684
# 3   -0.558457 -2.716223 -1.052451
# 4    0.975123 -0.319570 -0.292564
# ..        ...       ...       ...
# 495  2.157066 -1.871546  0.703141
# 496  1.449635  0.242413 -1.836469
# 497  0.641367 -1.871627  1.889389
# 498 -0.912208  1.996374  0.387436
# 499 -0.036234  1.602597  0.853615
#
# [500 rows x 3 columns]

# %%
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#             A         B         C         D
# 0   -1.337881 -1.283929 -0.819831  0.724206
# 1    1.152076  0.704105  1.324744  0.104367
# 2    1.854414  0.418244 -0.780684  0.614636
# 3   -0.558457 -2.716223 -1.052451  0.230284
# 4    0.975123 -0.319570 -0.292564  0.795858
# ..        ...       ...       ...       ...
# 495  2.157066 -1.871546  0.703141  0.893192
# 496  1.449635  0.242413 -1.836469  0.369547
# 497  0.641367 -1.871627  1.889389  0.817681
# 498 -0.912208  1.996374  0.387436  0.316231
# 499 -0.036234  1.602597  0.853615  0.105560
#
# [500 rows x 4 columns]

# %% [markdown]
# Generating DataFrame2 - df2

# %%
data2 = np.random.rand(20, 3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data=data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0   0.710157  0.732696  0.101564
# 1   0.324649  0.020770  0.448353
# 2   0.698634  0.863861  0.009996
# 3   0.634431  0.893997  0.957996
# 4   0.758595  0.122091  0.621298
# 5   0.791595  0.811752  0.343473
# 6   0.061296  0.758259  0.230343
# 7   0.948446  0.698233  0.808465
# 8   0.937750  0.293552  0.885700
# 9   0.759982  0.733352  0.891938
# 10  0.263162  0.592760  0.238324
# 11  0.498945  0.354885  0.007788
# 12  0.500484  0.370469  0.028742
# 13  0.922221  0.650506  0.311230
# 14  0.912008  0.882061  0.194706
# 15  0.188058  0.555692  0.121748
# 16  0.926926  0.175567  0.432277
# 17  0.942018  0.523699  0.615797
# 18  0.246727  0.019228  0.078555
# 19  0.577901  0.590018  0.918207

# %% [markdown]
# Histogram(single variable)

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black', bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=2, edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black', figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5), bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
# df1['A'].plot(kind="hist", bins=30)
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use("fivethirtyeight")
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.710157  0.732696  0.101564
# 1   0.324649  0.020770  0.448353
# 2   0.698634  0.863861  0.009996
# 3   0.634431  0.893997  0.957996
# 4   0.758595  0.122091  0.621298
# 5   0.791595  0.811752  0.343473
# 6   0.061296  0.758259  0.230343
# 7   0.948446  0.698233  0.808465
# 8   0.937750  0.293552  0.885700
# 9   0.759982  0.733352  0.891938
# 10  0.263162  0.592760  0.238324
# 11  0.498945  0.354885  0.007788
# 12  0.500484  0.370469  0.028742
# 13  0.922221  0.650506  0.311230
# 14  0.912008  0.882061  0.194706
# 15  0.188058  0.555692  0.121748
# 16  0.926926  0.175567  0.432277
# 17  0.942018  0.523699  0.615797
# 18  0.246727  0.019228  0.078555
# 19  0.577901  0.590018  0.918207

# %%
plt.style.use("dark_background")

# %%
df2['X'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.hist();

# %%
df2.hist();

# %% [markdown]
# Plot Types

# %%
# by default - line chart
df2['X'].plot()
# in x axis: index number
# in y axis: column values of x
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.710157  0.732696  0.101564
# 1   0.324649  0.020770  0.448353
# 2   0.698634  0.863861  0.009996
# 3   0.634431  0.893997  0.957996
# 4   0.758595  0.122091  0.621298
# 5   0.791595  0.811752  0.343473
# 6   0.061296  0.758259  0.230343
# 7   0.948446  0.698233  0.808465
# 8   0.937750  0.293552  0.885700
# 9   0.759982  0.733352  0.891938
# 10  0.263162  0.592760  0.238324
# 11  0.498945  0.354885  0.007788
# 12  0.500484  0.370469  0.028742
# 13  0.922221  0.650506  0.311230
# 14  0.912008  0.882061  0.194706
# 15  0.188058  0.555692  0.121748
# 16  0.926926  0.175567  0.432277
# 17  0.942018  0.523699  0.615797
# 18  0.246727  0.019228  0.078555
# 19  0.577901  0.590018  0.918207

# %%
df2.plot();

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.710157  0.732696  0.101564
# 1   0.324649  0.020770  0.448353
# 2   0.698634  0.863861  0.009996
# 3   0.634431  0.893997  0.957996
# 4   0.758595  0.122091  0.621298
# 5   0.791595  0.811752  0.343473
# 6   0.061296  0.758259  0.230343
# 7   0.948446  0.698233  0.808465
# 8   0.937750  0.293552  0.885700
# 9   0.759982  0.733352  0.891938
# 10  0.263162  0.592760  0.238324
# 11  0.498945  0.354885  0.007788
# 12  0.500484  0.370469  0.028742
# 13  0.922221  0.650506  0.311230
# 14  0.912008  0.882061  0.194706
# 15  0.188058  0.555692  0.121748
# 16  0.926926  0.175567  0.432277
# 17  0.942018  0.523699  0.615797
# 18  0.246727  0.019228  0.078555
# 19  0.577901  0.590018  0.918207

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
# df2.plot(stacked=True);
df2.plot(kind='bar', stacked=True);

# %%
# df2.plot(x='X', y='Y', stacked=True);;
# df2.plot(kind='bar', stacked=True);

# %%
# df2['X'].plot(kind='area')

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.710157  0.732696  0.101564
# 1   0.324649  0.020770  0.448353
# 2   0.698634  0.863861  0.009996
# 3   0.634431  0.893997  0.957996
# 4   0.758595  0.122091  0.621298
# 5   0.791595  0.811752  0.343473
# 6   0.061296  0.758259  0.230343
# 7   0.948446  0.698233  0.808465
# 8   0.937750  0.293552  0.885700
# 9   0.759982  0.733352  0.891938
# 10  0.263162  0.592760  0.238324
# 11  0.498945  0.354885  0.007788
# 12  0.500484  0.370469  0.028742
# 13  0.922221  0.650506  0.311230
# 14  0.912008  0.882061  0.194706
# 15  0.188058  0.555692  0.121748
# 16  0.926926  0.175567  0.432277
# 17  0.942018  0.523699  0.615797
# 18  0.246727  0.019228  0.078555
# 19  0.577901  0.590018  0.918207

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y')
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 5))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot.scatter(x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot(kind='area')
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.area(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# Bar Plot

# %%
df2
# Out:
#            X         Y         Z
# 0   0.710157  0.732696  0.101564
# 1   0.324649  0.020770  0.448353
# 2   0.698634  0.863861  0.009996
# 3   0.634431  0.893997  0.957996
# 4   0.758595  0.122091  0.621298
# 5   0.791595  0.811752  0.343473
# 6   0.061296  0.758259  0.230343
# 7   0.948446  0.698233  0.808465
# 8   0.937750  0.293552  0.885700
# 9   0.759982  0.733352  0.891938
# 10  0.263162  0.592760  0.238324
# 11  0.498945  0.354885  0.007788
# 12  0.500484  0.370469  0.028742
# 13  0.922221  0.650506  0.311230
# 14  0.912008  0.882061  0.194706
# 15  0.188058  0.555692  0.121748
# 16  0.926926  0.175567  0.432277
# 17  0.942018  0.523699  0.615797
# 18  0.246727  0.019228  0.078555
# 19  0.577901  0.590018  0.918207

# %%
df2['X'].plot.bar(figsize=(15, 5))
# Out:
# <Axes: >

# %%
df2['X'].plot.bar(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(10, 10))
# Out:
# <Axes: >

# %%
df2.plot.barh(figsize=(10, 10))
# Out:
# <Axes: >
