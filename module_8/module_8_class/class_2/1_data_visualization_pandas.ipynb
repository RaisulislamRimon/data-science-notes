# %% [markdown]
# Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data1 = np.random.randn(500, 3)
data1
# Out:
# array([[-0.14608259,  0.65274423,  1.70884098],
#        [-0.55919926, -1.8890198 , -0.10421826],
#        [ 2.38831549, -0.75514283, -0.75458472],
#        ...,
#        [-0.4036043 ,  0.45538282,  0.36063044],
#        [-1.41971554,  1.26232055, -0.39172985],
#        [-0.3441195 , -0.42857229, -0.61635818]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1 = pd.DataFrame(data=data1, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#             A         B         C
# 0   -0.146083  0.652744  1.708841
# 1   -0.559199 -1.889020 -0.104218
# 2    2.388315 -0.755143 -0.754585
# 3    1.557369  0.351459 -1.996468
# 4   -1.235697  0.870556 -1.392021
# ..        ...       ...       ...
# 495  0.006975  1.036607 -0.309840
# 496  0.205668  0.716134 -1.447263
# 497 -0.403604  0.455383  0.360630
# 498 -1.419716  1.262321 -0.391730
# 499 -0.344119 -0.428572 -0.616358
#
# [500 rows x 3 columns]

# %%
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#             A         B         C         D
# 0   -0.146083  0.652744  1.708841  0.237874
# 1   -0.559199 -1.889020 -0.104218  0.089482
# 2    2.388315 -0.755143 -0.754585  0.558089
# 3    1.557369  0.351459 -1.996468  0.970881
# 4   -1.235697  0.870556 -1.392021  0.512124
# ..        ...       ...       ...       ...
# 495  0.006975  1.036607 -0.309840  0.646976
# 496  0.205668  0.716134 -1.447263  0.865739
# 497 -0.403604  0.455383  0.360630  0.826959
# 498 -1.419716  1.262321 -0.391730  0.251408
# 499 -0.344119 -0.428572 -0.616358  0.837845
#
# [500 rows x 4 columns]

# %%
data2 = np.random.randn(20, 3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data=data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0   1.117885  0.517373  0.213854
# 1   1.197534  1.327136 -1.625112
# 2  -1.028240 -0.068574  0.529589
# 3  -0.899245  0.859579 -0.274983
# 4  -0.178732  1.427962  0.437911
# 5   2.304537 -1.460278 -0.580901
# 6  -0.505983 -1.384570 -0.559734
# 7  -1.056638  0.810886 -1.025053
# 8   1.147268  0.415693  1.270828
# 9  -1.845935  0.275180 -0.465254
# 10 -0.562622 -0.424612  1.049007
# 11 -0.204005  1.476838  0.003744
# 12 -0.405369  0.529928 -1.174706
# 13  0.400117  0.670338  0.050963
# 14  0.813659  0.199149  0.027270
# 15 -1.555948 -1.214328  0.251500
# 16  0.038430 -0.799253  1.399420
# 17  0.036745  0.537093 -0.523687
# 18  2.962630 -0.881340 -0.029721
# 19  0.829531  0.737290  0.770837

# %% [markdown]
# Histogram(single variable)

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black', bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=2, edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black', figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5), bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
# df1['A'].plot(kind="hist", bins=30)
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use("fivethirtyeight")
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   1.117885  0.517373  0.213854
# 1   1.197534  1.327136 -1.625112
# 2  -1.028240 -0.068574  0.529589
# 3  -0.899245  0.859579 -0.274983
# 4  -0.178732  1.427962  0.437911
# 5   2.304537 -1.460278 -0.580901
# 6  -0.505983 -1.384570 -0.559734
# 7  -1.056638  0.810886 -1.025053
# 8   1.147268  0.415693  1.270828
# 9  -1.845935  0.275180 -0.465254
# 10 -0.562622 -0.424612  1.049007
# 11 -0.204005  1.476838  0.003744
# 12 -0.405369  0.529928 -1.174706
# 13  0.400117  0.670338  0.050963
# 14  0.813659  0.199149  0.027270
# 15 -1.555948 -1.214328  0.251500
# 16  0.038430 -0.799253  1.399420
# 17  0.036745  0.537093 -0.523687
# 18  2.962630 -0.881340 -0.029721
# 19  0.829531  0.737290  0.770837

# %%
plt.style.use("dark_background")

# %%
df2['X'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.hist();

# %%
df2.hist();

# %% [markdown]
# Plot Types

# %%
# by default - line chart
df2['X'].plot()
# in x axis: index number
# in y axis: column values of x
# Out:
# <Axes: >

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   1.117885  0.517373  0.213854
# 1   1.197534  1.327136 -1.625112
# 2  -1.028240 -0.068574  0.529589
# 3  -0.899245  0.859579 -0.274983
# 4  -0.178732  1.427962  0.437911
# 5   2.304537 -1.460278 -0.580901
# 6  -0.505983 -1.384570 -0.559734
# 7  -1.056638  0.810886 -1.025053
# 8   1.147268  0.415693  1.270828
# 9  -1.845935  0.275180 -0.465254
# 10 -0.562622 -0.424612  1.049007
# 11 -0.204005  1.476838  0.003744
# 12 -0.405369  0.529928 -1.174706
# 13  0.400117  0.670338  0.050963
# 14  0.813659  0.199149  0.027270
# 15 -1.555948 -1.214328  0.251500
# 16  0.038430 -0.799253  1.399420
# 17  0.036745  0.537093 -0.523687
# 18  2.962630 -0.881340 -0.029721
# 19  0.829531  0.737290  0.770837

# %%
df2.plot();

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot.scatter(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot.line(x='X', y='Y', figsize=(12, 3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   1.117885  0.517373  0.213854
# 1   1.197534  1.327136 -1.625112
# 2  -1.028240 -0.068574  0.529589
# 3  -0.899245  0.859579 -0.274983
# 4  -0.178732  1.427962  0.437911
# 5   2.304537 -1.460278 -0.580901
# 6  -0.505983 -1.384570 -0.559734
# 7  -1.056638  0.810886 -1.025053
# 8   1.147268  0.415693  1.270828
# 9  -1.845935  0.275180 -0.465254
# 10 -0.562622 -0.424612  1.049007
# 11 -0.204005  1.476838  0.003744
# 12 -0.405369  0.529928 -1.174706
# 13  0.400117  0.670338  0.050963
# 14  0.813659  0.199149  0.027270
# 15 -1.555948 -1.214328  0.251500
# 16  0.038430 -0.799253  1.399420
# 17  0.036745  0.537093 -0.523687
# 18  2.962630 -0.881340 -0.029721
# 19  0.829531  0.737290  0.770837

# %%
# df2.plot(stacked=True);
df2.plot(kind='bar', stacked=True);

# %%
# df2.plot(x='X', y='Y', stacked=True);;
# df2.plot(kind='bar', stacked=True);

# %%
# df2['X'].plot(kind='area')
