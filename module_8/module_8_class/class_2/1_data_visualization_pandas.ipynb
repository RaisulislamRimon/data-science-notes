# %% [markdown]
# Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data1 = np.random.randn(500, 3)
data1
# Out:
# array([[-0.71472893,  0.90905899, -0.51643537],
#        [-0.83534675, -0.92471061,  0.12160155],
#        [-1.55139481, -0.62067023,  0.68193688],
#        ...,
#        [ 0.64304495, -0.27180097, -0.88076628],
#        [-0.99038715,  0.14145524,  0.13884589],
#        [ 1.42408902, -0.79095324,  0.33861731]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
df1 = pd.DataFrame(data=data1, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#             A         B         C
# 0   -0.714729  0.909059 -0.516435
# 1   -0.835347 -0.924711  0.121602
# 2   -1.551395 -0.620670  0.681937
# 3    0.113268  0.680590  0.321360
# 4    1.244640 -2.136501 -0.544864
# ..        ...       ...       ...
# 495 -1.483038  0.495161  0.897796
# 496 -0.149717  0.355657 -0.917599
# 497  0.643045 -0.271801 -0.880766
# 498 -0.990387  0.141455  0.138846
# 499  1.424089 -0.790953  0.338617
#
# [500 rows x 3 columns]

# %%
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#             A         B         C         D
# 0   -0.714729  0.909059 -0.516435  0.947103
# 1   -0.835347 -0.924711  0.121602  0.485022
# 2   -1.551395 -0.620670  0.681937  0.109890
# 3    0.113268  0.680590  0.321360  0.747295
# 4    1.244640 -2.136501 -0.544864  0.076809
# ..        ...       ...       ...       ...
# 495 -1.483038  0.495161  0.897796  0.667333
# 496 -0.149717  0.355657 -0.917599  0.033095
# 497  0.643045 -0.271801 -0.880766  0.259504
# 498 -0.990387  0.141455  0.138846  0.841319
# 499  1.424089 -0.790953  0.338617  0.872882
#
# [500 rows x 4 columns]

# %%
data2 = np.random.randn(20, 3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data=data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0  -0.898944  0.282652  1.281761
# 1  -1.145288 -0.960907 -1.369492
# 2  -1.622610 -0.156620  1.125366
# 3  -1.142447 -1.426112 -0.371647
# 4  -1.105285  2.380512  2.041338
# 5   1.687718  0.739478  2.395047
# 6  -1.537686  0.281667 -1.010182
# 7   0.648354 -0.294513 -0.530382
# 8  -1.595601 -0.432528  1.988075
# 9   0.972452  1.091955 -0.510545
# 10  1.547989 -0.215080  0.551450
# 11  0.311518 -0.395240 -1.956069
# 12 -0.418671 -1.640626  0.167529
# 13  0.401865  0.337875 -0.126410
# 14  1.044552 -0.196869 -1.309485
# 15  0.454711 -0.891945  0.404469
# 16  0.107684  0.366932 -0.790372
# 17  0.274742  1.860355 -0.204914
# 18 -2.532616 -0.335841 -2.076647
# 19  1.445702  0.210543 -0.823588

# %% [markdown]
# Histogram(single variable)

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black', bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=2, edgecolor="black")
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black', figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot()
# Out:
# <Axes: >

# %%
df1['A'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot(kind="hist", edgecolor="black", figsize=(12, 5), bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
# df1['A'].plot(kind="hist", bins=30)
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use("fivethirtyeight")
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0  -0.898944  0.282652  1.281761
# 1  -1.145288 -0.960907 -1.369492
# 2  -1.622610 -0.156620  1.125366
# 3  -1.142447 -1.426112 -0.371647
# 4  -1.105285  2.380512  2.041338
# 5   1.687718  0.739478  2.395047
# 6  -1.537686  0.281667 -1.010182
# 7   0.648354 -0.294513 -0.530382
# 8  -1.595601 -0.432528  1.988075
# 9   0.972452  1.091955 -0.510545
# 10  1.547989 -0.215080  0.551450
# 11  0.311518 -0.395240 -1.956069
# 12 -0.418671 -1.640626  0.167529
# 13  0.401865  0.337875 -0.126410
# 14  1.044552 -0.196869 -1.309485
# 15  0.454711 -0.891945  0.404469
# 16  0.107684  0.366932 -0.790372
# 17  0.274742  1.860355 -0.204914
# 18 -2.532616 -0.335841 -2.076647
# 19  1.445702  0.210543 -0.823588

# %%
plt.style.use("dark_background")

# %%
df2['X'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>
